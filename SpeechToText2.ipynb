# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleixbs/Python_bases/blob/main/SpeechToText2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-qoqwwcfo
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-qoqwwcfo
#   Resolved https://github.com/openai/whisper.git to commit 1cea4357687b676b293cb5473e1ade25f5b1cef7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 21.2 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20231106-py3-none-any.whl size=801359 sha256=cfa7c1db3d1daf2b9f52ed844c43936d625890f3a796633f86b5d9409b9a2e03
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yhf1278_/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...

# %%
# !sudo apt update && sudo apt install ffmpeg
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,195 kB]
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,275 kB]
# ...

# %%
# !whisper "audio1.mp4" --model large-v3
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:05.540]  But these are what I would consider to be full-stack users of geographic information systems.
# [00:05.760 --> 00:13.440]  They create data, they analyze data, they integrate GIS data or location data with the business systems that run those groups,
# [00:13.680 --> 00:17.060]  and they communicate with the public.
# [00:17.540 --> 00:22.080]  So full-stack, they use the soup-to-nuts capabilities of a GIS technology.
# [00:23.180 --> 00:26.820]  So is this approach and is this technology relevant in government?
# [00:26.820 --> 00:29.500]  I'd say yes, we have evidence that it is.
# [00:30.000 --> 00:32.400]  This is a map of the United States, obviously.
# [00:33.380 --> 00:38.480]  The red dots represent the local governments that are using GIS as a core business system.
# ...
